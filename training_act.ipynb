# %% [markdown]
# <a href="https://colab.research.google.com/github/Moncif11/mainGame/blob/main/training_act.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤗 x 🦾: Training ACT with LeRobot Notebook
#
# Welcome to the **LeRobot ACT training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `ACT` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `ACT` policy for 100,000 steps typically takes **about 1.5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer.
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
import sys
PY = sys.executable
print(PY)
# Out:
# /usr/bin/python3.real

# %%
import sys
PY = sys.executable

# !rm -rf /content/lerobot
# !git clone https://github.com/huggingface/lerobot.git /content/lerobot
# !{PY} -m pip install -U pip setuptools wheel
# !cd /content/lerobot && {PY} -m pip install -e .
# Out:
# Cloning into '/content/lerobot'...
# remote: Enumerating objects: 47673, done.
# remote: Counting objects: 100% (687/687), done.
# remote: Compressing objects: 100% (354/354), done.
# remote: Total 47673 (delta 569), reused 333 (delta 333), pack-reused 46986 (from 2)
# Receiving objects: 100% (47673/47673), 238.96 MiB | 43.55 MiB/s, done.
# Resolving deltas: 100% (30253/30253), done.
# Filtering content: 100% (45/45), 69.03 MiB | 24.72 MiB/s, done.
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (75.2.0)
# Collecting setuptools
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.46.3)
# Collecting wheel
#   Downloading wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.0)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.7 MB/s eta 0:00:00
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Downloading wheel-0.47.0-py3-none-any.whl (32 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.46.3
#     Uninstalling wheel-0.46.3:
#       Successfully uninstalled wheel-0.46.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed pip-26.0.1 setuptools-82.0.1 wheel-0.47.0
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch<2.11.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.10.0+cu128)
# Requirement already satisfied: torchvision<0.26.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.25.0+cu128)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.0.2)
# Requirement already satisfied: opencv-python-headless<4.14.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (4.13.0.92)
# Requirement already satisfied: Pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (11.3.0)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.8.2)
# Collecting draccus==0.10.0 (from lerobot==0.5.2)
#   Using cached draccus-0.10.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (1.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.32.4)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (1.2.3)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.7.0)
# Collecting packaging<26.0,>=24.2 (from lerobot==0.5.2)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (4.67.3)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (3.31.10)
# Collecting setuptools<81.0.0,>=71.0.0 (from lerobot==0.5.2)
#   Using cached setuptools-80.10.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting mergedeep~=1.3 (from draccus==0.10.0->lerobot==0.5.2)
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (6.0.3)
# Collecting pyyaml-include~=1.4 (from draccus==0.10.0->lerobot==0.5.2)
#   Downloading pyyaml_include-1.4.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (0.10.2)
# Collecting typing-inspect~=0.9.0 (from draccus==0.10.0->lerobot==0.5.2)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (0.0.4)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<2.11.0,>=2.7->lerobot==0.5.2) (1.5.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.5.2)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.11.0,>=2.7->lerobot==0.5.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.11.0,>=2.7->lerobot==0.5.2) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.1.2)
# Downloading draccus-0.10.0-py3-none-any.whl (71 kB)
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pyyaml_include-1.4.1-py3-none-any.whl (19 kB)
# Downloading setuptools-80.10.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.7 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.5.2-0.editable-py3-none-any.whl size=13376 sha256=736b065d76fcce1b8e1caf6e43c91296cd0d8214186988a479be89892203ab01
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c5tkb41j/wheels/09/b4/fe/75732b1d640db96ba1f856f2b7328b232a03b696a39cb59686
# Successfully built lerobot
# Installing collected packages: setuptools, pyyaml-include, packaging, mypy-extensions, mergedeep, typing-inspect, draccus, lerobot
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#       Successfully uninstalled setuptools-82.0.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.0
#     Uninstalling packaging-26.0:
#       Successfully uninstalled packaging-26.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [lerobot]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed draccus-0.10.0 lerobot-0.5.2 mergedeep-1.3.4 mypy-extensions-1.1.0 packaging-25.0 pyyaml-include-1.4.1 setuptools-80.10.2 typing-inspect-0.9.0

# %%
import sys
PY = sys.executable
print("Kernel executable:", PY)
# !{PY} --version
# !{PY} -m pip --version
# Out:
# Kernel executable: /usr/bin/python3.real
# Python 3.12.13
# pip 26.0.1 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .
# Out:
# fatal: destination path 'lerobot' already exists and is not an empty directory.
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch<2.11.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.10.0+cu128)
# Requirement already satisfied: torchvision<0.26.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.25.0+cu128)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.0.2)
# Requirement already satisfied: opencv-python-headless<4.14.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (4.13.0.92)
# Requirement already satisfied: Pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (11.3.0)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.8.2)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.10.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (1.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.32.4)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (1.2.3)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.7.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (25.0)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (4.67.3)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (3.31.10)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (80.10.2)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (0.9.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (0.0.4)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<2.11.0,>=2.7->lerobot==0.5.2) (1.5.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.5.2) (1.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.11.0,>=2.7->lerobot==0.5.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.11.0,>=2.7->lerobot==0.5.2) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.1.2)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.5.2-0.editable-py3-none-any.whl size=13376 sha256=eb8b80971169450a6b4ebd7865511b586e50bd267cf219cd5ae9fdc0962ca092
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1idmrkqh/wheels/09/b4/fe/75732b1d640db96ba1f856f2b7328b232a03b696a39cb59686
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.5.2
#     Uninstalling lerobot-0.5.2:
#       Successfully uninstalled lerobot-0.5.2
# Successfully installed lerobot-0.5.2

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login
# Out:
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: moncif_11 (moncif_110) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
HF_USER = "Moncif"

# %% [markdown]
# ## Start training ACT with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this. Set to `False` if you do not plan on using Weights & Biases.

# %%
import sys
PY = sys.executable
print("Using:", PY)

# !{PY} -m pip install -U pip setuptools wheel
# !{PY} -m pip install torch torchvision
# Out:
# Using: /usr/bin/python3.real
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (80.10.2)
# Collecting setuptools
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.47.0)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (25.0)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.10.2
#     Uninstalling setuptools-80.10.2:
#       Successfully uninstalled setuptools-80.10.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# lerobot 0.5.2 requires setuptools<81.0.0,>=71.0.0, but you have setuptools 82.0.1 which is incompatible.
# Successfully installed setuptools-82.0.1
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
import sys
PY = sys.executable

# !{PY} -c "import torch; print('torch:', torch.__version__); print('cuda available:', torch.cuda.is_available())"
# Out:
# torch: 2.10.0+cu128
# cuda available: True

# %%
import sys
PY = sys.executable
print("Using:", PY)

# !{PY} -m pip install -U av
# !cd /content/lerobot && {PY} -m pip install -e ".[dataset]"
# Out:
# Using: /usr/bin/python3.real
# Collecting av
#   Downloading av-17.0.1-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Downloading av-17.0.1-cp311-abi3-manylinux_2_28_x86_64.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 162.4 MB/s  0:00:00
# Installing collected packages: av
# Successfully installed av-17.0.1
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch<2.11.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.10.0+cu128)
# Requirement already satisfied: torchvision<0.26.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.25.0+cu128)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.0.2)
# Requirement already satisfied: opencv-python-headless<4.14.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (4.13.0.92)
# Requirement already satisfied: Pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (11.3.0)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.8.2)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.10.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (1.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.32.4)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (1.2.3)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.7.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (25.0)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (4.67.3)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (3.31.10)
# Collecting setuptools<81.0.0,>=71.0.0 (from lerobot==0.5.2)
#   Using cached setuptools-80.10.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: datasets<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (4.0.0)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (2.2.2)
# Collecting pyarrow<30.0.0,>=21.0.0 (from lerobot==0.5.2)
#   Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: torchcodec<0.11.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.2) (0.10.0+cu128)
# Collecting jsonlines<5.0.0,>=4.0.0 (from lerobot==0.5.2)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.2) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (3.25.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (3.13.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.16.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.5.2) (26.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.0->lerobot==0.5.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.0->lerobot==0.5.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.0->lerobot==0.5.2) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.2) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<2.11.0,>=2.7->lerobot==0.5.2) (1.5.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.5.2) (1.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.2) (1.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->lerobot==0.5.2) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.11.0,>=2.7->lerobot==0.5.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.11.0,>=2.7->lerobot==0.5.2) (3.0.3)
# Collecting av<16.0.0,>=15.0.0 (from lerobot==0.5.2)
#   Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.1.2)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (48.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 157.9 MB/s  0:00:00
# Using cached setuptools-80.10.2-py3-none-any.whl (1.1 MB)
# Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 133.9 MB/s  0:00:00
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.5.2-0.editable-py3-none-any.whl size=13376 sha256=c686a9a5794d74ba87dac29d729c2ff12af9651d3434f06ed8953e94766f2c18
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q_xpyy9z/wheels/09/b4/fe/75732b1d640db96ba1f856f2b7328b232a03b696a39cb59686
# Successfully built lerobot
# Installing collected packages: setuptools, pyarrow, jsonlines, av, lerobot
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#       Successfully uninstalled setuptools-82.0.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: av
#     Found existing installation: av 17.0.1
#     Uninstalling av-17.0.1:
#       Successfully uninstalled av-17.0.1
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.5.2
#     Uninstalling lerobot-0.5.2:
#       Successfully uninstalled lerobot-0.5.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [lerobot]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed av-15.1.0 jsonlines-4.0.0 lerobot-0.5.2 pyarrow-24.0.0 setuptools-80.10.2

# %%
import sys
PY = sys.executable
HF_USER = "Moncif"

# !cd /content/lerobot && {PY} -m lerobot.scripts.lerobot_train \
  --dataset.repo_id={HF_USER}/move_green_right \
  --policy.type=act \
  --output_dir=outputs/train/act_move_green_right \
  --job_name=act_move_green_right \
  --policy.device=cuda \
  --wandb.enable=true \
  --policy.repo_id={HF_USER}/act_move_green_right
# Out:
# INFO 2026-04-23 22:27:50 ot_train.py:207 {'batch_size': 8,
#  'checkpoint_path': None,
#  'cudnn_deterministic': False,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'Moncif/move_green_right',
#              'return_uint8': False,
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 8, 'n_episodes': 50, 'use_async_envs': True},
#  'eval_freq': 20000,
#  'job_name': 'act_move_green_right',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_move_green_right',
#  'peft': None,
#  'persistent_workers': True,
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': 'Moncif/act_move_green_right',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_peft': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'prefetch_factor': 4,
#  'rabc_epsilon': 1e-06,
#  'rabc_head_mode': 'sparse',
#  'rabc_kappa': 0.01,
#  'rabc_progress_path': None,
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 100000,
#  'tolerance_s': 0.0001,
#  'use_policy_training_preset': True,
#  'use_rabc': False,
#  'wandb': {'add_tags': True,
#            'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2026-04-23 22:27:57 db_utils.py:117 Logs will be synced with wandb.
# INFO 2026-04-23 22:27:57 db_utils.py:118 Track this run --> https://wandb.ai/moncif_110/lerobot/runs/qwdiowev
# INFO 2026-04-23 22:27:57 ot_train.py:231 Creating dataset
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING 2026-04-23 22:27:57 ls/_http.py:916 Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading (incomplete total...): 83.4kB [00:00, 112kB/s]
# Fetching 4 files: 100% 4/4 [00:00<00:00,  5.19it/s]
# Download complete: : 85.6kB [00:00, 90.3kB/s]
# INFO 2026-04-23 22:27:58 eo_utils.py:110 Using video codec: libsvtav1
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files: 100% 4/4 [00:00<00:00, 24314.81it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):   0% 2.50k/64.5M [00:00<1:06:45, 16.1kB/s]
# Downloading (incomplete total...):   0% 287k/64.5M [00:00<00:49, 1.29MB/s]
# Downloading (incomplete total...): 64.5MB [00:00, 117MB/s]
# Fetching 9 files: 100% 9/9 [00:00<00:00, 13.53it/s]
# Download complete: : 64.5MB [00:00, 117MB/s]              INFO 2026-04-23 22:27:59 ot_train.py:249 Creating policy
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#
#   0% 0.00/44.7M [00:00<?, ?B/s]
#  21% 9.25M/44.7M [00:00<00:00, 96.7MB/s]
# 100% 44.7M/44.7M [00:00<00:00, 181MB/s]
# INFO 2026-04-23 22:28:01 ot_train.py:316 Creating optimizer and scheduler
# INFO 2026-04-23 22:28:01 ot_train.py:351 Output dir: outputs/train/act_move_green_right
# INFO 2026-04-23 22:28:01 ot_train.py:358 cfg.steps=100000 (100K)
# INFO 2026-04-23 22:28:01 ot_train.py:359 dataset.num_frames=5762 (6K)
# INFO 2026-04-23 22:28:01 ot_train.py:360 dataset.num_episodes=10
# INFO 2026-04-23 22:28:01 ot_train.py:363 Effective batch size: 8 x 1 = 8
# INFO 2026-04-23 22:28:01 ot_train.py:364 num_learnable_params=51597190 (52M)
# INFO 2026-04-23 22:28:01 ot_train.py:365 num_total_params=51597190 (52M)
# Training:   0% 0/100000 [00:00<?, ?step/s]INFO 2026-04-23 22:28:01 ot_train.py:430 Start offline training on a fixed dataset, with effective batch size: 8
# Download complete: : 64.5MB [00:02, 26.0MB/s]
# Download complete: : 64.5MB [00:02, 26.0MB/s]
# Download complete: : 64.5MB [00:02, 25.9MB/s]
# Download complete: : 64.5MB [00:02, 25.8MB/s]
# Download complete: : 64.5MB [00:04, 14.8MB/s]
# Training:   0% 199/100000 [00:18<2:14:08, 12.40step/s]INFO 2026-04-23 22:28:20 ot_train.py:465 step:200 smpl:2K ep:3 epch:0.28 loss:6.800 grdn:158.442 lr:1.0e-05 updt_s:0.088 data_s:0.006
# Training:   0% 399/100000 [00:35<2:16:18, 12.18step/s]INFO 2026-04-23 22:28:36 ot_train.py:465 step:400 smpl:3K ep:6 epch:0.56 loss:2.999 grdn:87.687 lr:1.0e-05 updt_s:0.078 data_s:0.003
# Training:   1% 599/100000 [00:51<2:14:01, 12.36step/s]INFO 2026-04-23 22:28:52 ot_train.py:465 step:600 smpl:5K ep:8 epch:0.83 loss:2.531 grdn:76.072 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:   1% 799/100000 [01:07<2:11:39, 12.56step/s]INFO 2026-04-23 22:29:09 ot_train.py:465 step:800 smpl:6K ep:11 epch:1.11 loss:2.219 grdn:69.905 lr:1.0e-05 updt_s:0.078 data_s:0.003
# Training:   1% 999/100000 [01:23<2:14:35, 12.26step/s]INFO 2026-04-23 22:29:25 ot_train.py:465 step:1K smpl:8K ep:14 epch:1.39 loss:1.988 grdn:67.911 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:   1% 1199/100000 [01:40<2:12:43, 12.41step/s]INFO 2026-04-23 22:29:41 ot_train.py:465 step:1K smpl:10K ep:17 epch:1.67 loss:1.790 grdn:64.412 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:   1% 1399/100000 [01:56<2:11:25, 12.50step/s]INFO 2026-04-23 22:29:57 ot_train.py:465 step:1K smpl:11K ep:19 epch:1.94 loss:1.620 grdn:61.406 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:   2% 1599/100000 [02:12<2:13:42, 12.27step/s]INFO 2026-04-23 22:30:14 ot_train.py:465 step:2K smpl:13K ep:22 epch:2.22 loss:1.482 grdn:58.693 lr:1.0e-05 updt_s:0.079 data_s:0.003
# Training:   2% 1799/100000 [02:29<2:12:52, 12.32step/s]INFO 2026-04-23 22:30:30 ot_train.py:465 step:2K smpl:14K ep:25 epch:2.50 loss:1.347 grdn:56.299 lr:1.0e-05 updt_s:0.078 data_s:0.003
# Training:   2% 1999/100000 [02:45<2:10:08, 12.55step/s]INFO 2026-04-23 22:30:46 ot_train.py:465 step:2K smpl:16K ep:28 epch:2.78 loss:1.220 grdn:53.164 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:   2% 2199/100000 [03:01<2:13:37, 12.20step/s]INFO 2026-04-23 22:31:02 ot_train.py:465 step:2K smpl:18K ep:31 epch:3.05 loss:1.104 grdn:49.694 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:
lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:  21% 20599/100000 [27:59<1:48:34, 12.19step/s]INFO 2026-04-23 22:56:01 ot_train.py:465 step:21K smpl:165K ep:286 epch:28.60 loss:0.097 grdn:10.034 lr:1.0e-05 updt_s:0.077 data_s:0.002
# Training:  21% 20799/100000 [28:15<1:45:46, 12.48step/s]INFO 2026-04-23 22:56:17 ot_train.py:465 step:21K smpl:166K ep:289 epch:28.88 loss:0.097 grdn:10.274 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:  21% 20999/100000 [28:31<1:45:38, 12.46step/s]INFO 2026-04-23 22:56:33 ot_train.py:465 step:21K smpl:168K ep:292 epch:29.16 loss:0.095 grdn:10.019 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:  21% 21199/100000 [28:48<1:48:35, 12.10step/s]INFO 2026-04-23 22:56:49 ot_train.py:465 step:21K smpl:170K ep:294 epch:29.43 loss:0.095 grdn:9.914 lr:1.0e-05 updt_s:0.078 data_s:0.003
# Training:  21% 21399/100000 [29:04<1:44:55, 12.49step/s]INFO 2026-04-23 22:57:05 ot_train.py:465 step:21K smpl:171K ep:297 epch:29.71 loss:0.096 grdn:10.021 lr:1.0e-05 updt_s:0.076 data_s:0.003
# Training:  22% 21599/100000 [29:20<1:43:40, 12.60step/s]INFO 2026-04-23 22:57:21 ot_train.py:465 step:22K smpl:173K ep:300 epch:29.99 loss:0.095 grdn:9.813 lr:1.0e-05 updt_s:0.077 data_s:0.003
# Training:  22% 21651/100000 [29:24<1:49:19, 11.94step/s]Error in sys.excepthook:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/wandb/sdk/lib/exit_hooks.py", line 54, in exc_handler
#     traceback.print_exception(exc_type, exc, tb)
#   File "/usr/lib/python3.12/traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 418, in _extract_from_extended_frame_gen
#     for f, (lineno, end_lineno, colno, end_colno) in frame_gen:
#                                                      ^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 355, in _walk_tb_with_full_positions
#     positions = _get_code_position(tb.tb_frame.f_code, tb.tb_lasti)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 369, in _get_code_position
#     return next(itertools.islice(positions_gen, instruction_index // 2, None))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# Original exception was:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/lerobot/src/lerobot/scripts/lerobot_train.py", line 581, in <module>
#     main()
#   File "/content/lerobot/src/lerobot/scripts/lerobot_train.py", line 577, in main
#     train()
#   File "/content/lerobot/src/lerobot/configs/parser.py", line 233, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot/src/lerobot/scripts/lerobot_train.py", line 443, in train
#     train_tracker, output_dict = update_policy(
#                                  ^^^^^^^^^^^^^^
#   File "/content/lerobot/src/lerobot/scripts/lerobot_train.py", line 148, in update_policy
#     if has_method(accelerator.unwrap_model(policy, keep_fp32_wrapper=True), "update"):
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/accelerate/accelerator.py", line 3232, in unwrap_model
#     return extract_model_from_parallel(model, keep_fp32_wrapper, keep_torch_compile)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/accelerate/utils/other.py", line 257, in extract_model_from_parallel
#     if is_deepspeed_available():
#        ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/accelerate/utils/imports.py", line 149, in is_deepspeed_available
#     return _is_package_available("deepspeed")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/accelerate/utils/imports.py", line 52, in _is_package_available
#     package_exists = importlib.util.find_spec(pkg_name) is not None
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib.util>", line 100, in find_spec
#   File "<frozen importlib._bootstrap>", line 1256, in _find_spec
# KeyboardInterrupt

# %% [markdown]
# ## Login into Hugging Face Hub.
# ### Now after training is done login into the Hugging Face hub and upload the last checkpoint.

# %%
import os

base = "/content/lerobot/outputs/train/act_move_green_right"

for root, dirs, files in os.walk(base):
    level = root.replace(base, "").count(os.sep)
    indent = "  " * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = "  " * (level + 1)
    for f in files:
        print(f"{subindent}{f}")
# Out:
# act_move_green_right/
#   checkpoints/
#     020000/
#       pretrained_model/
#         model.safetensors
#         policy_postprocessor_step_0_unnormalizer_processor.safetensors
#         policy_preprocessor.json
#         policy_preprocessor_step_3_normalizer_processor.safetensors
#         config.json
#         train_config.json
#         policy_postprocessor.json
#       training_state/
#         training_step.json
#         rng_state.safetensors
#         optimizer_param_groups.json
#         optimizer_state.safetensors
#   wandb/
#     debug-internal.log
#     debug.log
#     run-20260423_222751-qwdiowev/
#       run-qwdiowev.wandb
#       tmp/
#         code/
#       files/
#         requirements.txt
#         output.log
#         wandb-metadata.json
#         config.yaml
#         wandb-summary.json
#       logs/
#         debug-internal.log
#         debug-core.log
#         debug.log

# %%
from huggingface_hub import HfApi

api = HfApi()
repo_id = "Moncif/act_move_green_right"

api.create_repo(repo_id=repo_id, repo_type="model", exist_ok=True)

api.upload_folder(
    folder_path="/content/lerobot/outputs/train/act_move_green_right/checkpoints/020000/pretrained_model",
    repo_id=repo_id,
    repo_type="model",
)

print("Model upload finished.")
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     760     try:
# --> 761         response.raise_for_status()
#     762     except httpx.HTTPStatusError as e:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_models.py in raise_for_status(self)
#     828         message = message.format(self, error_type=error_type)
# --> 829         raise HTTPStatusError(message, request=request, response=self)
#     830
#
# HTTPStatusError: Client error '404 Not Found' for url 'https://huggingface.co/api/models/Moncif/act_move_green_right/tree/main?recursive=true&expand=false'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# /tmp/ipykernel_1654/2438019947.py in <cell line: 0>()
#       6 api = HfApi()
#       7 repo_id = f"{HF_USERNAME}/{HF_REPO_NAME}"
# ----> 8 files_in_repo = api.list_repo_files(repo_id=repo_id)
#       9
#      10 print(f"Files in {repo_id}:")
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#      86         kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#      87
# ---> 88         return fn(*args, **kwargs)
#      89
#      90     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in list_repo_files(self, repo_id, revision, repo_type, token)
#    3641         return [
#    3642             f.rfilename
# -> 3643             for f in self.list_repo_tree(
#    3644                 repo_id=repo_id, recursive=True, revision=revision, repo_type=repo_type, token=token
#    3645             )
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in list_repo_tree(self, repo_id, path_in_repo, recursive, expand, revision, repo_type, token)
#    3776         encoded_path_in_repo = "/" + quote(path_in_repo, safe="") if path_in_repo else ""
#    3777         tree_url = f"{self.endpoint}/api/{repo_type}s/{repo_id}/tree/{revision}{encoded_path_in_repo}"
# -> 3778         for path_info in paginate(path=tree_url, headers=headers, params={"recursive": recursive, "expand": expand}):
#    3779             yield (RepoFile(**path_info) if path_info["type"] == "file" else RepoFolder(**path_info))
#    3780
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_pagination.py in paginate(path, params, headers)
#      34     session = get_session()
#      35     r = session.get(path, params=params, headers=headers)
# ---> 36     hf_raise_for_status(r)
#      37     yield from r.json()
#      38
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     845             repo_err.repo_type = repo_type
#     846             repo_err.repo_id = repo_id
# --> 847             raise repo_err from e
#     848
#     849         elif response.status_code == 400:
#
# RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-69eaa4ab-08235e040593a9370f6d7a88;54b8b702-87be-45fb-87ab-0a09b2ef9bc4)
#
# Repository Not Found for url: https://huggingface.co/api/models/Moncif/act_move_green_right/tree/main?recursive=true&expand=false.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication

# %% [markdown]
# ### Configure Hugging Face Token
#
# Add your HF_TOKEN (AKA Secret) to Google Colab to enable Colab to access your HF repositories. This is optional and might need modification if you are using another cloud provider.

# %%
from google.colab import userdata
import os

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# Verify token is loaded (optional)
if os.getenv("HF_TOKEN"):
    print("Hugging Face token loaded successfully.")
else:
    print("Error: Hugging Face token not found. Please set it as a Colab secret named 'HF_TOKEN'.")

# %%
from google.colab import userdata
userdata.get('HF_TOKEN')

# %% [markdown]
# ### Download files from Hugging Face Hub into Colab
#
# Now, you can use `hf_hub_download` to pull the files directly to your Colab environment. You can then download them from Colab to your local machine. This is optional.

# %%
from huggingface_hub import hf_hub_download

# Your Hugging Face repository details
HF_CONFIG_REPO_ID = "${HF_USER}/act_move_green_right"
HF_POLICY_REPO_ID = "${HF_USER}/act_move_green_right"

# Define the files to download
config_file_name = "train_config.json"
model_file_name = "model.safetensors"
tokenizer_processor_file_name = "tokenizer_processor.safetensors"

# Download train_config.json
train_config_path = hf_hub_download(repo_id=HF_CONFIG_REPO_ID, filename=config_file_name)
print(f"Downloaded {config_file_name} to: {train_config_path}")

# Download the trained model files
model_path = hf_hub_download(repo_id=HF_POLICY_REPO_ID, filename=model_file_name)
print(f"Downloaded {model_file_name} to: {model_path}")

tokenizer_processor_path = hf_hub_download(repo_id=HF_POLICY_REPO_ID, filename=tokenizer_processor_file_name)
print(f"Downloaded {tokenizer_processor_file_name} to: {tokenizer_processor_path}")

print("\nAll specified files have been downloaded to your Colab environment.")
print("You can find them in the paths printed above. To download them to your local machine, right-click on the files in the Colab file browser (left sidebar) and select 'Download'.")

# %% [markdown]
# ### Verify `train_config.json` existence locally. This is needed for restarting training and testing of the policy.

# %%
# !ls -l /content/lerobot/outputs/train/hf_act_record0/

# %%
HF_USERNAME = "${HF_USER}"
HF_REPO_NAME = "act-configs"

# !hf repo-files $HF_USERNAME/$HF_REPO_NAME

# %%
# !hf auth login

# %%
# !hf upload ${HF_USER}/hf_act_record0 \
  /content/lerobot/outputs/train/hf_act_record0/checkpoints/last/pretrained_model

# %%
# !hf auth login

# %% [markdown]
# ### Create a new repository on Hugging Face Hub
#
# This command will create a new repository under your Hugging Face account.

# %%
HF_USERNAME = "${HF_USER}"
HF_REPO_NAME = "act-configs"

# !hf repo create $HF_REPO_NAME --type model --private --organization $HF_USERNAME

# %%
### Upload `train_config.json` to the new repository
HF_USERNAME = "${HF_USER}"
HF_REPO_NAME = "act-configs"
LOCAL_CONFIG_PATH = "/content/lerobot/outputs/train/hf_act_record0/train_config.json"

# !hf upload $HF_USERNAME/$HF_REPO_NAME "$LOCAL_CONFIG_PATH" train_config.json
